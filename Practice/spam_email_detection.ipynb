# %%
import pandas as pd

# %%
email_data_frame: str = open(r"datasets/spam.csv", encoding='latin1').readlines()

for index, line in enumerate(email_data_frame):
    email_data_frame[index] = line.split(maxsplit=1)

print(email_data_frame)
# Out:
# [['ÿþv\x001\x00,\x00v\x002\x00'], ['\x00h\x00a\x00m\x00,\x00"\x00G\x00o\x00', '\x00u\x00n\x00t\x00i\x00l\x00 \x00j\x00u\x00r\x00o\x00n\x00g\x00 \x00p\x00o\x00i\x00n\x00t\x00,\x00 \x00c\x00r\x00a\x00z\x00y\x00.\x00.\x00 \x00A\x00v\x00a\x00i\x00l\x00a\x00b\x00l\x00e\x00 \x00o\x00n\x00l\x00y\x00 \x00i\x00n\x00 \x00b\x00u\x00g\x00i\x00s\x00 \x00n\x00 \x00g\x00r\x00e\x00a\x00t\x00 \x00w\x00o\x00r\x00l\x00d\x00 \x00l\x00a\x00 \x00e\x00 \x00b\x00u\x00f\x00f\x00e\x00t\x00.\x00.\x00.\x00 \x00C\x00i\x00n\x00e\x00 \x00t\x00h\x00e\x00r\x00e\x00 \x00g\x00o\x00t\x00 \x00a\x00m\x00o\x00r\x00e\x00 \x00w\x00a\x00t\x00.\x00.\x00.\x00"\x00\n'], ['\x00h\x00a\x00m\x00,\x00O\x00k\x00', '\x00l\x00a\x00r\x00.\x00.\x00.\x00 \x00J\x00o\x00k\x00i\x00n\x00g\x00 \x00w\x00i\x00f\x00 \x00u\x00 \x00o\x00n\x00i\x00.\x00.\x00.\x00\n'], ['\x00s\x00p\x00a\x00m\x00,\x00F\x00r\x00e\x00e\x00', "\x00e\x00n\x00t\x00r\x00y\x00 \x00i\x00n\x00 \x002\x00 \x00a\x00 \x00w\x00k\x00l\x00y\x00 \x00c\x00o\x00m\x00p\x00 \x00t\x00o\x00
# ...
